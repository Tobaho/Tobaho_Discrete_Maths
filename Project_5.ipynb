# %% [markdown]
# <a href="https://colab.research.google.com/github/Tobaho/Tobaho_Discrete_Maths/blob/main/Project_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project Part #5 : CPSMA 3913
# #Discrete Mathematics
# #Structures
# #Oluwatobi Afolabi

# %% [markdown]
# For this part of the project, I will be using my favorite marvel movie "spiderman" and it's sequel.

# %% [markdown]
# ![spiderman.jpg](data:image/jpeg;base64,...)

# %%
# !pip install anytree
# Out:
# ...
#      |████████████████████████████████| 41 kB 215 kB/s
# ...

# %%
from anytree import Node, RenderTree
from anytree.exporter import DotExporter
from IPython.display import display, Image
SM = Node("SPIDER MAN") #root
AS =Node("AMAZING SPIDERMAN",parent=SM)
SM1= Node("SPIDERMAN:2", parent=SM)
AMS2= Node("AMAZING SPIDERMAN 2", parent=AS)
SHC =Node("SPIDERMAN HOMECOMING",parent=SM)
SFH = Node("SPIDERMAN FAR FROM HOME", parent=SM)

DotExporter(SM).to_picture("SM.png")
display(Image("SM.png"))

# %% [markdown]
# For this part of the project, I chose to use my favorite marvel studio movie; Spider-man. I have a lot of favorite spiderman movies, but I chose 5 of them.
#
# This graph is a direct graph. There are 6 vertices including the root vertex and 5 edges altogether. Thhis graph does not have not cycle representation.
#
# I was experiencing a little difficulty doing the webwork assignment, but doing this project, I think I have a better understanding of this module.
