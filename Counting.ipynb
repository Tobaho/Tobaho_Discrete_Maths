# %% [markdown]
# <a href="https://colab.research.google.com/github/Tobaho/Tobaho_Discrete_Maths/blob/main/Counting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Project Part # 4: CPSMA 3133 Discrete Mathematics
#
# ## Counting
#
# ### OLUWATOBI AFOLABI
#
# ### Instructor: Dr. Jacob

# %% [markdown]
# I am going to continue with the balls I used in probability. ![colorful-ball-beautiful-basket-15234451.jpg](data:image/jpeg;base64,...)

# %%
YBO = ['Yellow','Blue','Orange']

# %% [markdown]
# Yellow,blue and orange balls.

# %% [markdown]
# I used three balls, so there should be a sequence of 10. There are $3^{10}$

# %%
3**10
# Out:
# 59049

# %% [markdown]
#  If there are $n$ objects and $k$ slots but order does not matter,we can use this formular
#
# $$
# \binom{n+k-1}{k-1} = \binom{n+k-1}{n}
# $$

# %%
import math

math.factorial(13)/(math.factorial(10)*math.factorial(3))
# Out:
# 286.0

# %%
from itertools import combinations_with_replacement

print(list(combinations_with_replacement(YBO,10)))
# Out:
# [('Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow'), ('Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Blue'), ('Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Orange'), ('Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Blue', 'Blue'), ('Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Blue', 'Orange'), ('Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Orange', 'Orange'), ('Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Blue', 'Blue', 'Blue'), ('Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Blue', 'Blue', 'Orange'), ('Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Blue', 'Orange', 'Orange'), ('Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow', 'Orange', 'Orange', 'Orange'
# ...

# %% [markdown]
# I am going to use 20 as the total number of balls.

# %%
len(list(combinations_with_replacement(YBO,20)))
# Out:
# 231

# %% [markdown]
# #Without Replacement

# %%
print(math.factorial(10))
# Out:
# 3628800

# %%
from itertools import permutations
print(list(permutations(YBO,10)))
# Out:
# []

# %%
from itertools import permutations
print(list(permutations(YBO,3)))
# Out:
# [('Yellow', 'Blue', 'Orange'), ('Yellow', 'Orange', 'Blue'), ('Blue', 'Yellow', 'Orange'), ('Blue', 'Orange', 'Yellow'), ('Orange', 'Yellow', 'Blue'), ('Orange', 'Blue', 'Yellow')]

# %% [markdown]
# I am not really sure why the permutations for 10 was empty and wasn't for 3.

# %% [markdown]
# Actually, I think because i had three balls and not 10 balls. There was no way, it could have been able to arrange 10 balls when I do not have up to that.

# %% [markdown]
# When order does not matter, this will happen

# %%
math.factorial(3)/(math.factorial(3)*math.factorial(1))
# Out:
# 1.0

# %%
math.factorial(10)/(math.factorial(0)*math.factorial(10))
# Out:
# 1.0

# %% [markdown]
# This does not really matter, I was playing around with numbers.

# %%
math.factorial(3)/(math.factorial(3)*math.factorial(3))
# Out:
# 0.16666666666666666

# %%
from itertools import combinations
print(list(combinations(YBO,3)))
# Out:
# [('Yellow', 'Blue', 'Orange')]

# %% [markdown]
# For the last quesiton ) What is the coefficent of the 5th order of (x − 3)9
# ?

# %%
math.factorial(9)/(math.factorial(5)*math.factorial(9-5))
# Out:
# 126.0

# %%
126*((-3)**4)
# Out:
# 10206

# %% [markdown]
# The coefficient of the 5th order is 10206.
